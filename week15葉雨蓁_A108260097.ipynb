# %% [markdown]
# <a href="https://colab.research.google.com/github/ja156/computational-and-thinking/blob/master/week15%E8%91%89%E9%9B%A8%E8%93%81_A108260097.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
n = 1
while n<5:
  print("變動n是",n)
  n=n+1

  print("Finish")
# Out:
# 變動n是 1
# Finish
# 變動n是 2
# Finish
# 變動n是 3
# Finish
# 變動n是 4
# Finish

# %%
x=0

while x <1000:
  print("hello")
  x = x+1
# Out:
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# ...

# %%
times=0
while times < 1000:
  print("hello")
  times = times+1
  print("這是第",times,"次的hello")
# Out:
# hello
# 這是第 1 次的hello
# hello
# 這是第 2 次的hello
# hello
# 這是第 3 次的hello
# hello
# 這是第 4 次的hello
# hello
# 這是第 5 次的hello
# hello
# 這是第 6 次的hello
# hello
# 這是第 7 次的hello
# hello
# 這是第 8 次的hello
# hello
# 這是第 9 次的hello
# hello
# 這是第 10 次的hello
# hello
# 這是第 11 次的hello
# hello
# 這是第 12 次的hello
# hello
# 這是第 13 次的hello
# hello
# 這是第 14 次的hello
# hello
# 這是第 15 次的hello
# hello
# 這是第 16 次的hello
# hello
# 這是第 17 次的hello
# hello
# 這是第 18 次的hello
# hello
# 這是第 19 次的hello
# hello
# 這是第 20 次的hello
# hello
# 這是第 21 次的hello
# hello
# 這是第 22 次的hello
# hello
# 這是第 23 次的hello
# hello
# 這是第 24 次的hello
# hello
# 這是第 25 次的hello
# hello
# 這是第 26 次的hello
# hello
# 這是第 27 次的hello
# hello
# 這是第 28 次的hello
# hello
# 這是第 29 次的hello
# hello
# 這是第 30 次的hello
# hello
# 這是第 31 次的hello
# hello
# 這是第 32 次的hello
# hello
# 這是第 33 次的hello
# hello
# 這是第 34 次的hello
# hello
# 這是第 35 次的hello
# hello
# 這是第 36 次的hello
# hello
# 這是第 37 次的hello
# hello
# 這是第 38 次的hello
# hello
# 這是第 39 次的hello
# hello
# 這是第 40 次的hello
# hello
# ...

# %%
x = 0
result = 0

while result<=50:
  x = x+1
  result = result +x
  print("最後加的x是",x)
# Out:
# 最後加的x是 1
# 最後加的x是 2
# 最後加的x是 3
# 最後加的x是 4
# 最後加的x是 5
# 最後加的x是 6
# 最後加的x是 7
# 最後加的x是 8
# 最後加的x是 9
# 最後加的x是 10

# %%
sum=0
i=0
while sum <=1000:
  i+=1
  sum+=i*i
  print("最小的n值為",i)
# Out:
# 最小的n值為 1
# 最小的n值為 2
# 最小的n值為 3
# 最小的n值為 4
# 最小的n值為 5
# 最小的n值為 6
# 最小的n值為 7
# 最小的n值為 8
# 最小的n值為 9
# 最小的n值為 10
# 最小的n值為 11
# 最小的n值為 12
# 最小的n值為 13
# 最小的n值為 14
